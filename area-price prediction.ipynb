# %%
import matplotlib.pyplot as plt

# %%
import pandas as pd
import numpy as np
import seaborn as sns
from sklearn import linear_model

# %%
df =pd.read_csv("homeprices.csv")
df
# Out:
#    area   price
# 0  2600  550000
# 1  3000  565000
# 2  3200  610000
# 3  3600  680000
# 4  4000  725000

# %%
sns.lmplot(x='area',y='price',data=df)

# %%
reg = linear_model.LinearRegression()

# %%
reg.fit(df[['area']],df['price'])
# Out:
# LinearRegression()

# %%
reg.predict([[1000]])
# Out:
# C:\Users\sujal\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([316404.10958904])

# %%
reg.coef_
# Out:
# array([135.78767123])

# %%
reg.intercept_
# Out:
# 180616.43835616432
